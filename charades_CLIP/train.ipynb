# %%
# !python -u train.py \
  --ann   charades/annotations/charades_sta.json \
  --video_root  charades/videos \
  --output_csv   charades_zeroshot_results.csv \
  --sample_rate  5 \
  --window_size  2.0 \
  --stride       1.0
# Out:
# ^C
